# %%
import pandas as pd
import numpy as np
import os
import koreanize_matplotlib
import seaborn as sns
# %config InlineBackend.figure_format = 'retina'  #선명하게 만들기
#한글폰트 가져오기
from matplotlib import rc
rc('font', family='NanumGothic')
import matplotlib.pyplot as plt

# 결측치 확인하는 라이브러리
import missingno as msno
import chardet

from sklearn.cluster import KMeans

path = 'C:/Users/sim/Desktop/medical/grouping by quantile'
os.chdir(path)
print(os.getcwd())
# Out:
# C:\Users\sim\Desktop\medical\grouping by quantile

# %%
male = pd.read_csv('male_final_grouping.csv')
male_origin = male.copy()

# %%
female = pd.read_csv('female_final_grouping.csv')
female_origin = female.copy()

# %%
male.head()
# Out:
#   Blood_Pressure_group      Anemia_group              Liver_Kidney_group  \
# 0         Hypertension  Suspected Anemia  Suspected liver/kidney disease
# 1               Normal  Suspected Anemia  Suspected liver/kidney disease
# 2         Hypertension            Normal  Suspected liver/kidney disease
# 3         Hypertension            Normal  Suspected liver/kidney disease
# 4               Normal  Suspected Anemia                          Normal
#
#         Obesity_group Smoking_Alcohol_group Vision_group Hearing_group  \
# 0  Weight loss needed               Alcohol  Vision risk        Normal
# 1              Normal   Smoking and Alcohol       Normal        Normal
# 2  Weight loss needed   Smoking and Alcohol  Vision risk        Normal
# 3  Weight loss needed               healthy  Vision risk        Normal
# 4  Weight gain needed   Smoking and Alcohol  Vision risk        Normal
#
#        Diabetes_group      Cardiovascular_group
# 0  Suspected Diabetes  Suspected Cardiovascular
# ...

# %%
male.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51095 entries, 0 to 51094
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Blood_Pressure_group   51095 non-null  object
#  1   Anemia_group           51095 non-null  object
#  2   Liver_Kidney_group     51095 non-null  object
#  3   Obesity_group          51095 non-null  object
#  4   Smoking_Alcohol_group  51095 non-null  object
#  5   Vision_group           51095 non-null  object
#  6   Hearing_group          51095 non-null  object
#  7   Diabetes_group         51095 non-null  object
#  8   Cardiovascular_group   51095 non-null  object
# dtypes: object(9)
# memory usage: 3.5+ MB

# %%
female.head()
# Out:
#   Blood_Pressure_group      Anemia_group              Liver_Kidney_group  \
# 0               Normal  Suspected Anemia                          Normal
# 1         Hypertension            Normal                          Normal
# 2         Hypertension            Normal  Suspected liver/kidney disease
# 3         Hypertension  Suspected Anemia                          Normal
# 4         Hypertension            Normal  Suspected liver/kidney disease
#
#         Obesity_group Smoking_Alcohol_group Vision_group Hearing_group  \
# 0  Weight gain needed               Alcohol       Normal        Normal
# 1              Normal               Alcohol       Normal        Normal
# 2  Weight loss needed               Alcohol  Vision risk        Normal
# 3  Weight gain needed               Alcohol  Vision risk        Normal
# 4  Weight gain needed               healthy  Vision risk        Normal
#
#        Diabetes_group      Cardiovascular_group
# 0  Suspected Diabetes                    Normal
# ...

# %%
female.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53724 entries, 0 to 53723
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Blood_Pressure_group   53724 non-null  object
#  1   Anemia_group           53724 non-null  object
#  2   Liver_Kidney_group     53724 non-null  object
#  3   Obesity_group          53724 non-null  object
#  4   Smoking_Alcohol_group  53724 non-null  object
#  5   Vision_group           53724 non-null  object
#  6   Hearing_group          53724 non-null  object
#  7   Diabetes_group         53724 non-null  object
#  8   Cardiovascular_group   53724 non-null  object
# dtypes: object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# ## 성별코드 == 1 : male
# ## 성별코드 == 2 : female

# %%
male['성별코드'] = 1
female['성별코드'] = 2

# %%
male
# Out:
#       Blood_Pressure_group      Anemia_group              Liver_Kidney_group  \
# 0             Hypertension  Suspected Anemia  Suspected liver/kidney disease
# 1                   Normal  Suspected Anemia  Suspected liver/kidney disease
# 2             Hypertension            Normal  Suspected liver/kidney disease
# 3             Hypertension            Normal  Suspected liver/kidney disease
# 4                   Normal  Suspected Anemia                          Normal
# ...                    ...               ...                             ...
# 51090         Hypertension  Suspected Anemia  Suspected liver/kidney disease
# 51091               Normal  Suspected Anemia  Suspected liver/kidney disease
# 51092               Normal            Normal  Suspected liver/kidney disease
# 51093         Hypertension            Normal  Suspected liver/kidney disease
# 51094         Hypertension            Normal  Suspected liver/kidney disease
#
# ...

# %%
female
# Out:
#       Blood_Pressure_group      Anemia_group              Liver_Kidney_group  \
# 0                   Normal  Suspected Anemia                          Normal
# 1             Hypertension            Normal                          Normal
# 2             Hypertension            Normal  Suspected liver/kidney disease
# 3             Hypertension  Suspected Anemia                          Normal
# 4             Hypertension            Normal  Suspected liver/kidney disease
# ...                    ...               ...                             ...
# 53719         Hypertension            Normal  Suspected liver/kidney disease
# 53720         Hypertension            Normal  Suspected liver/kidney disease
# 53721         Hypertension  Suspected Anemia  Suspected liver/kidney disease
# 53722               Normal            Normal  Suspected liver/kidney disease
# 53723               Normal  Suspected Anemia  Suspected liver/kidney disease
#
# ...

# %%
# 51095 + 53724 = 104819 확인핑
Final_grouping = pd.concat([male, female], ignore_index=True)

# %%
Final_grouping
# Out:
#        Blood_Pressure_group      Anemia_group              Liver_Kidney_group  \
# 0              Hypertension  Suspected Anemia  Suspected liver/kidney disease
# 1                    Normal  Suspected Anemia  Suspected liver/kidney disease
# 2              Hypertension            Normal  Suspected liver/kidney disease
# 3              Hypertension            Normal  Suspected liver/kidney disease
# 4                    Normal  Suspected Anemia                          Normal
# ...                     ...               ...                             ...
# 104814         Hypertension            Normal  Suspected liver/kidney disease
# 104815         Hypertension            Normal  Suspected liver/kidney disease
# 104816         Hypertension  Suspected Anemia  Suspected liver/kidney disease
# 104817               Normal            Normal  Suspected liver/kidney disease
# 104818               Normal  Suspected Anemia  Suspected liver/kidney disease
#
# ...

# %%
# 열 순서 재배치
columns = ['성별코드', 'Blood_Pressure_group', 'Anemia_group', 'Liver_Kidney_group', 
           'Obesity_group', 'Smoking_Alcohol_group', 'Vision_group', 'Hearing_group', 
           'Diabetes_group', 'Cardiovascular_group']

Final_grouping = Final_grouping[columns]

# %%
Final_grouping
# Out:
#         성별코드 Blood_Pressure_group      Anemia_group  \
# 0          1         Hypertension  Suspected Anemia
# 1          1               Normal  Suspected Anemia
# 2          1         Hypertension            Normal
# 3          1         Hypertension            Normal
# 4          1               Normal  Suspected Anemia
# ...      ...                  ...               ...
# 104814     2         Hypertension            Normal
# 104815     2         Hypertension            Normal
# 104816     2         Hypertension  Suspected Anemia
# 104817     2               Normal            Normal
# 104818     2               Normal  Suspected Anemia
#
#                     Liver_Kidney_group       Obesity_group  \
# 0       Suspected liver/kidney disease  Weight loss needed
# 1       Suspected liver/kidney disease              Normal
# 2       Suspected liver/kidney disease  Weight loss needed
# 3       Suspected liver/kidney disease  Weight loss needed
# ...

# %%
Final_grouping.to_csv('Final_grouping.csv', index=False)
